# %%
import pandas as pd

# %%
person_info = {
    "Person": ["Milk","Alex","Ken","Jack"],
    "Height": [155,165,138,180],
    "Favor Color": ["White","Red","Black","Blue"]
}

# %%
new_df = pd.DataFrame(person_info)

# %%
new_df
# Out:
#   Person  Height Favor Color
# 0   Milk     155       White
# 1   Alex     165         Red
# 2    Ken     138       Black
# 3   Jack     180        Blue

# %%
new_df.shape
# Out:
# (4, 3)

# %%
rows , columns = new_df.shape

# %%
rows
# Out:
# 4

# %%
columns
# Out:
# 3

# %%
new_df.head(2)
# Out:
#   Person  Height Favor Color
# 0   Milk     155       White
# 1   Alex     165         Red

# %%
new_df.tail(2)
# Out:
#   Person  Height Favor Color
# 2    Ken     138       Black
# 3   Jack     180        Blue

# %%
new_df[1:3]
# Out:
#   Person  Height Favor Color
# 1   Alex     165         Red
# 2    Ken     138       Black

# %%
new_df.columns
# Out:
# Index(['Person', 'Height', 'Favor Color'], dtype='object')

# %%
new_df["Person"]
# Out:
# 0    Milk
# 1    Alex
# 2     Ken
# 3    Jack
# Name: Person, dtype: object

# %%
new_df.Person
# Out:
# 0    Milk
# 1    Alex
# 2     Ken
# 3    Jack
# Name: Person, dtype: object

# %%
new_df[["Person" , "Favor Color"]]
# Out:
#   Person Favor Color
# 0   Milk       White
# 1   Alex         Red
# 2    Ken       Black
# 3   Jack        Blue
